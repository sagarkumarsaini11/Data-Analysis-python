# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
df=pd.read_excel("E:/e drive data/Datasets/New Microsoft Excel Worksheet.xlsx",sheet_name="player")

# %%
df
# Out:
#     virat  35  100000
# 0   rohit  34  100000
# 1  hardik  29   60000
# 2   dhoni  36  100000
# 3   raina  34   80000
# 4  yuvraj  36   90000

# %%
df=pd.read_excel("E:/e drive data/Datasets/New Microsoft Excel Worksheet.xlsx",sheet_name="player",header=None)
df
# Out:
#         0   1       2
# 0   virat  35  100000
# 1   rohit  34  100000
# 2  hardik  29   60000
# 3   dhoni  36  100000
# 4   raina  34   80000
# 5  yuvraj  36   90000

# %%
df=pd.read_excel("E:/e drive data/Datasets/New Microsoft Excel Worksheet.xlsx",sheet_name="player",header=None,names=["name","age","salary"])
df
# Out:
#      name  age  salary
# 0   virat   35  100000
# 1   rohit   34  100000
# 2  hardik   29   60000
# 3   dhoni   36  100000
# 4   raina   34   80000
# 5  yuvraj   36   90000

# %%
df=pd.read_excel("E:/e drive data/Datasets/New Microsoft Excel Worksheet.xlsx",sheet_name="player",names=["name","age","salary"])
df
# Out:
#      name  age  salary
# 0   rohit   34  100000
# 1  hardik   29   60000
# 2   dhoni   36  100000
# 3   raina   34   80000
# 4  yuvraj   36   90000

# %%
df=pd.read_excel("E:/e drive data/Datasets/New Microsoft Excel Worksheet.xlsx",sheet_name=0,header=None,names=["name","age","salary"])
df
# Out:
#      name  age  salary
# 0   virat   35  100000
# 1   rohit   34  100000
# 2  hardik   29   60000
# 3   dhoni   36  100000
# 4   raina   34   80000
# 5  yuvraj   36   90000

# %%
df1=pd.read_excel("E:\e drive data\POWER BI\live data and dataset\HR Data.xlsx",nrows=100)
df1
# Out:
#    Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0        Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1         No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2        Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3         No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4         No      Travel_Rarely     25 - 34  Current Employees        R&D
# ..       ...                ...         ...                ...        ...
# 95        No      Travel_Rarely     45 - 54  Current Employees        R&D
# 96        No      Travel_Rarely    Under 25  Current Employees      Sales
# 97        No         Non-Travel     25 - 34  Current Employees      Sales
# 98        No      Travel_Rarely     Over 55  Current Employees      Sales
# 99        No         Non-Travel     35 - 44  Current Employees        R&D
#
#      Education Field     emp no  Employee Number  Gender  \
# ...

# %%
df1=pd.read_excel("E:\e drive data\POWER BI\live data and dataset\HR Data.xlsx",nrows=100,skiprows=5)
df1
# Out:
#      No      Travel_Rarely   25 - 34  Current Employees  R&D          Medical  \
# 0    No  Travel_Frequently   25 - 34  Current Employees  R&D    Life Sciences
# 1    No      Travel_Rarely   Over 55  Current Employees  R&D          Medical
# 2    No      Travel_Rarely   25 - 34  Current Employees  R&D    Life Sciences
# 3    No  Travel_Frequently   35 - 44  Current Employees  R&D    Life Sciences
# 4    No      Travel_Rarely   35 - 44  Current Employees  R&D          Medical
# ..  ...                ...       ...                ...  ...              ...
# 95  Yes      Travel_Rarely   35 - 44       Ex-Employees   HR  Human Resources
# 96   No      Travel_Rarely   25 - 34  Current Employees  R&D    Life Sciences
# 97  Yes  Travel_Frequently  Under 25       Ex-Employees  R&D    Life Sciences
# 98   No      Travel_Rarely   25 - 34  Current Employees  R&D            Other
# 99   No         Non-Travel   35 - 44  Current Employees  R&D    Life Sciences
#
# ...

# %%
df1=pd.read_excel("E:\e drive data\POWER BI\live data and dataset\HR Data.xlsx",nrows=100,skiprows=range(1,10))
df1
# Out:
#    Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0         No      Travel_Rarely     35 - 44  Current Employees        R&D
# 1         No      Travel_Rarely     35 - 44  Current Employees        R&D
# 2         No      Travel_Rarely     25 - 34  Current Employees        R&D
# 3         No      Travel_Rarely     25 - 34  Current Employees        R&D
# 4         No      Travel_Rarely     25 - 34  Current Employees        R&D
# ..       ...                ...         ...                ...        ...
# 95        No         Non-Travel     35 - 44  Current Employees        R&D
# 96        No         Non-Travel     Over 55  Current Employees         HR
# 97        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 98       Yes      Travel_Rarely     25 - 34       Ex-Employees      Sales
# 99        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#     Education Field     emp no  Employee Number  Gender  \
# ...

# %%
import pandas as pd

# %%
#csv
df=pd.read_csv("E:\e drive data\ML\Amit Mishra Github\Recommendation-System-master/Recommendation-System-master\Zomato\Restaurant names and Metadata.csv")
df
# Out:
#                                        Name  \
# 0                           Beyond Flavours
# 1                                  Paradise
# 2                                  Flechazo
# 3            Shah Ghouse Hotel & Restaurant
# 4                Over The Moon Brew Company
# ..                                      ...
# 100                               IndiBlaze
# 101                            Sweet Basket
# 102                        Angaara Counts 3
# 103                             Wich Please
# 104  Republic Of Noodles - Lemon Tree Hotel
#
#                                                  Links   Cost  \
# 0    https://www.zomato.com/hyderabad/beyond-flavou...    800
# 1    https://www.zomato.com/hyderabad/paradise-gach...    800
# 2    https://www.zomato.com/hyderabad/flechazo-gach...  1,300
# 3    https://www.zomato.com/hyderabad/shah-ghouse-h...    800
# 4    https://www.zomato.com/hyderabad/over-the-moon...  1,200
# ...

# %%
list_dfs=pd.read_html("E:/e drive data/ML/ML files/List of named colors — Matplotlib 3.5.2 documentation.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2556\1891851453.py in <module>
# ----> 1 list_dfs=pd.read_html("E:/e drive data/ML/ML files/List of named colors — Matplotlib 3.5.2 documentation.html")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# -> 1113     return _parse(
#    1114         flavor=flavor,
#    1115         io=io,
#
# ...

# %%
import sqlalchemy
import pymysql

# %%
eng=sqlalchemy.create_engine("mysql+pymysql://root:Sagar@563@localhost/apple")

# %%
df=pd.read_sql("select * from emp",con=eng)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# ...

# %%
import pandas as pd

# %%
#Data Frame
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame([[101,'ram',75],[102,'sayam',72]])
df
# Out:
#      0      1   2
# 0  101    ram  75
# 1  102  sayam  72

# %%
df=pd.DataFrame([[101,'ram',75],[102,'sayam',72]],columns=['id','name','mark'])
df
# Out:
#     id   name  mark
# 0  101    ram    75
# 1  102  sayam    72

# %%
df=pd.DataFrame([[101,'ram',75],[102,'sayam',72]],columns=['id','name','mark'],index=['a','b'])
df
# Out:
#     id   name  mark
# a  101    ram    75
# b  102  sayam    72

# %%
df=pd.DataFrame({'roll no.':[101,102,103],'name':['rahul','sohan','mohan'],'sal':[10000,15000,20000]})
df
# Out:
#    roll no.   name    sal
# 0       101  rahul  10000
# 1       102  sohan  15000
# 2       103  mohan  20000

# %%
df=pd.DataFrame({'roll no.':[101,102,103],'name':['rahul','sohan','mohan'],'sal':[10000,15000,20000]}, index=['a','b','c'])
df
# Out:
#    roll no.   name    sal
# a       101  rahul  10000
# b       102  sohan  15000
# c       103  mohan  20000

# %%
#df.at[indel,col_label]
df.at['b','name']
# Out:
# 'sohan'

# %%
df.at['c','sal']
# Out:
# 20000

# %%
#df.iat[int_index,int_col_label]
df.iat[1,1]  #for indivisual element
# Out:
# 'sohan'

# %%
df.iat[-2,-2] #for indivisual element
# Out:
# 'sohan'

# %%
#df.loc[index]
s=df.loc['b']
print(s)
print(type(s))
# Out:
# roll no.      102
# name        sohan
# sal         15000
# Name: b, dtype: object
# <class 'pandas.core.series.Series'>

# %%
#df.iloc[int_index]
df.iloc[2]
# Out:
# roll no.      103
# name        mohan
# sal         20000
# Name: c, dtype: object

# %%
#df[col_label]
df["name"]
# Out:
# a    rahul
# b    sohan
# c    mohan
# Name: name, dtype: object

# %%
df
# Out:
#    roll no.   name    sal
# a       101  rahul  10000
# b       102  sohan  15000
# c       103  mohan  20000

# %%
df["roll no."]
# Out:
# a    101
# b    102
# c    103
# Name: roll no., dtype: int64

# %%
df.name
# Out:
# a    rahul
# b    sohan
# c    mohan
# Name: name, dtype: object

# %%
df.sal
# Out:
# a    10000
# b    15000
# c    20000
# Name: sal, dtype: int64

# %%
df.roll no.
# Out:
#   File "C:\Users\india\AppData\Local\Temp\ipykernel_2556\2586974027.py", line 1
#     df.roll no.
#             ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (3, 3)

# %%
df.shape[0] #for rows
# Out:
# 3

# %%
df.shape[1] #for columns
# Out:
# 3

# %%
df.columns
# Out:
# Index(['roll no.', 'name', 'sal'], dtype='object')

# %%
df.columns.value_counts()
# Out:
# roll no.    1
# name        1
# sal         1
# dtype: int64

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.size
# Out:
# 9

# %%
df.dtypes
# Out:
# roll no.     int64
# name        object
# sal          int64
# dtype: object

# %%
df
# Out:
#    roll no.   name    sal
# a       101  rahul  10000
# b       102  sohan  15000
# c       103  mohan  20000

# %%
#df.loc[['index','index',....]]
df.loc[['a','b']]
# Out:
#    roll no.   name    sal
# a       101  rahul  10000
# b       102  sohan  15000

# %%
#df.iloc[[int_index,int_index,....]]
df.iloc[[0,1]]
# Out:
#    roll no.   name    sal
# a       101  rahul  10000
# b       102  sohan  15000

# %%
df[['roll no.','name']]
# Out:
#    roll no.   name
# a       101  rahul
# b       102  sohan
# c       103  mohan

# %%
import pandas as pd
df=pd.read_csv("E:\e drive data\Datasets\movies ...csv")
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.index=range(1,155,2)
df
# Out:
#                                    Film    Genre            Lead Studio  \
# 1            Zack and Miri Make a Porno  Romance  The Weinstein Company
# 3                       Youth in Revolt   Comedy  The Weinstein Company
# 5    You Will Meet a Tall Dark Stranger   Comedy            Independent
# 7                          When in Rome   Comedy                 Disney
# 9                 What Happens in Vegas   Comedy                    Fox
# ..                                  ...      ...                    ...
# 145                 Across the Universe  romance            Independent
# 147                       A Serious Man    Drama              Universal
# 149                  A Dangerous Method    Drama            Independent
# 151                          27 Dresses   Comedy                    Fox
# 153                (500) Days of Summer   comedy                    Fox
#
#      Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.index=range(0,77)
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.index=df.Genre  #I can make index any column

# %%
df
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
# ...                                     ...      ...                    ...
# romance                 Across the Universe  romance            Independent
# Drama                         A Serious Man    Drama              Universal
# Drama                    A Dangerous Method    Drama            Independent
# Comedy                           27 Dresses   Comedy                    Fox
# comedy                 (500) Days of Summer   comedy                    Fox
#
# ...

# %%
df.index=range(0,77)
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.index=df.Genre
df
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
# ...                                     ...      ...                    ...
# romance                 Across the Universe  romance            Independent
# Drama                         A Serious Man    Drama              Universal
# Drama                    A Dangerous Method    Drama            Independent
# Comedy                           27 Dresses   Comedy                    Fox
# comedy                 (500) Days of Summer   comedy                    Fox
#
# ...

# %%
df.loc['comedy']
# Out:
# Film                 (500) Days of Summer
# Genre                              comedy
# Lead Studio                           Fox
# Audience score %                       81
# Profitability                       8.096
# Rotten Tomatoes %                      87
# Worldwide Gross                   $60.72
# Year                                 2009
# Name: comedy, dtype: object

# %%
df.loc["Comedy"]
# Out:
#                                       Film   Genre            Lead Studio  \
# Genre
# Comedy                     Youth in Revolt  Comedy  The Weinstein Company
# Comedy  You Will Meet a Tall Dark Stranger  Comedy            Independent
# Comedy                        When in Rome  Comedy                 Disney
# Comedy               What Happens in Vegas  Comedy                    Fox
# Comedy                     Valentine's Day  Comedy           Warner Bros.
# Comedy                      The Ugly Truth  Comedy            Independent
# Comedy                        The Proposal  Comedy                 Disney
# Comedy              The Invention of Lying  Comedy           Warner Bros.
# Comedy                  The Heartbreak Kid  Comedy              Paramount
# Comedy                    The Back-up Plan  Comedy                    CBS
# Comedy              She's Out of My League  Comedy              Paramount
# Comedy                Sex and the City Two  Comedy           Warner Bros.
# ...

# %%
df.loc["Comedy"].shape
# Out:
# (41, 8)

# %%
df.head()
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
#
#          Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  \
# Genre
# Romance                70       1.747542                 64         $41.94
# Comedy                 52       1.090000                 68         $19.62
# Comedy                 35       1.211818                 43         $26.66
# Comedy                 44       0.000000                 15         $43.04
# Comedy                 72       6.267647                 28        $219.37
#
#          Year
# Genre
# Romance  2008
# ...

# %%
df.head(3)
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
#
#          Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  \
# Genre
# Romance                70       1.747542                 64         $41.94
# Comedy                 52       1.090000                 68         $19.62
# Comedy                 35       1.211818                 43         $26.66
#
#          Year
# Genre
# Romance  2008
# Comedy   2010
# Comedy   2010

# %%
df.tail()
# Out:
#                          Film    Genre  Lead Studio  Audience score %  \
# Genre
# romance   Across the Universe  romance  Independent                84
# Drama           A Serious Man    Drama    Universal                64
# Drama      A Dangerous Method    Drama  Independent                89
# Comedy             27 Dresses   Comedy          Fox                71
# comedy   (500) Days of Summer   comedy          Fox                81
#
#          Profitability  Rotten Tomatoes % Worldwide Gross  Year
# Genre
# romance       0.652603                 54         $29.37   2007
# Drama         4.382857                 89         $30.68   2009
# Drama         0.448645                 79          $8.97   2011
# Comedy        5.343622                 40        $160.31   2008
# comedy        8.096000                 87         $60.72   2009

# %%
df.tail(3)
# Out:
#                         Film   Genre  Lead Studio  Audience score %  \
# Genre
# Drama     A Dangerous Method   Drama  Independent                89
# Comedy            27 Dresses  Comedy          Fox                71
# comedy  (500) Days of Summer  comedy          Fox                81
#
#         Profitability  Rotten Tomatoes % Worldwide Gross  Year
# Genre
# Drama        0.448645                 79          $8.97   2011
# Comedy       5.343622                 40        $160.31   2008
# comedy       8.096000                 87         $60.72   2009

# %%
# create a dataframe
#dff = pd.DataFrame({'column1': [1, 2, 3, 4], 'column2': ['a', 'b', 'c', 'd']})

# set the max_rows option to None
#pd.set_option('display.max_rows', None)

# display the dataframe
#dff

# %%
#pd.set_option("display.max_rows",None)

# %%
df.shape
# Out:
# (77, 8)

# %%
df.head()
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
#
#          Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  \
# Genre
# Romance                70       1.747542                 64         $41.94
# Comedy                 52       1.090000                 68         $19.62
# Comedy                 35       1.211818                 43         $26.66
# Comedy                 44       0.000000                 15         $43.04
# Comedy                 72       6.267647                 28        $219.37
#
#          Year
# Genre
# Romance  2008
# ...

# %%
df
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Romance          Zack and Miri Make a Porno  Romance  The Weinstein Company
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
# ...                                     ...      ...                    ...
# romance                 Across the Universe  romance            Independent
# Drama                         A Serious Man    Drama              Universal
# Drama                    A Dangerous Method    Drama            Independent
# Comedy                           27 Dresses   Comedy                    Fox
# comedy                 (500) Days of Summer   comedy                    Fox
#
# ...

# %%
df.tail(-1)
# Out:
#                                        Film    Genre            Lead Studio  \
# Genre
# Comedy                      Youth in Revolt   Comedy  The Weinstein Company
# Comedy   You Will Meet a Tall Dark Stranger   Comedy            Independent
# Comedy                         When in Rome   Comedy                 Disney
# Comedy                What Happens in Vegas   Comedy                    Fox
# Drama                   Water For Elephants    Drama       20th Century Fox
# ...                                     ...      ...                    ...
# romance                 Across the Universe  romance            Independent
# Drama                         A Serious Man    Drama              Universal
# Drama                    A Dangerous Method    Drama            Independent
# Comedy                           27 Dresses   Comedy                    Fox
# comedy                 (500) Days of Summer   comedy                    Fox
#
# ...

# %%
df2=pd.read_csv("E:/e drive data/Datasets/brics.csv")
df2
# Out:
#   Code       country    capital    area  population
# 0   BR        Brazil   Brasilia   8.516      200.40
# 1   RU        Russia     Moscow  17.100      143.50
# 2   IN         India  New Delhi   3.286     1252.00
# 3   CH         China    Beijing   9.597     1357.00
# 4   SA  South Africa   Pretoria   1.221       52.98

# %%
df2.head(-1)
# Out:
#   Code country    capital    area  population
# 0   BR  Brazil   Brasilia   8.516       200.4
# 1   RU  Russia     Moscow  17.100       143.5
# 2   IN   India  New Delhi   3.286      1252.0
# 3   CH   China    Beijing   9.597      1357.0

# %%
df2.head(-2)
# Out:
#   Code country    capital    area  population
# 0   BR  Brazil   Brasilia   8.516       200.4
# 1   RU  Russia     Moscow  17.100       143.5
# 2   IN   India  New Delhi   3.286      1252.0

# %%
df2.tail(-1)
# Out:
#   Code       country    capital    area  population
# 1   RU        Russia     Moscow  17.100      143.50
# 2   IN         India  New Delhi   3.286     1252.00
# 3   CH         China    Beijing   9.597     1357.00
# 4   SA  South Africa   Pretoria   1.221       52.98

# %%
df2.tail(-2)
# Out:
#   Code       country    capital   area  population
# 2   IN         India  New Delhi  3.286     1252.00
# 3   CH         China    Beijing  9.597     1357.00
# 4   SA  South Africa   Pretoria  1.221       52.98

# %%
df=pd.read_csv("E:\e drive data\Datasets\movies ...csv")
df.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
df.sample(10)
# Out:
#                                   Film      Genre       Lead Studio  \
# 17              The Invention of Lying     Comedy      Warner Bros.
# 37  Nick and Norah's Infinite Playlist     Comedy              Sony
# 65                   Gnomeo and Juliet  Animation            Disney
# 58                    It's Complicated     Comedy         Universal
# 53                           Leap Year     Comedy         Universal
# 45                          Mamma Mia!     Comedy         Universal
# 41                         Monte Carlo    Romance  20th Century Fox
# 74                  A Dangerous Method      Drama       Independent
# 26                  Sex and the City 2     Comedy      Warner Bros.
# 7                             Waitress    Romance       Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 17                47       1.751351                 56         $32.40   2009
# ...

# %%
df.sample(n=10,replace=False)
# Out:
#                                    Film    Genre       Lead Studio  \
# 41                          Monte Carlo  Romance  20th Century Fox
# 15             The Time Traveler's Wife    Drama         Paramount
# 7                              Waitress  Romance       Independent
# 32                   Over Her Dead Body   Comedy          New Line
# 52                    Letters to Juliet   Comedy            Summit
# 68                            Fireproof    Drama       Independent
# 9                       Valentine's Day   Comedy      Warner Bros.
# 45                           Mamma Mia!   Comedy         Universal
# 20  The Curious Case of Benjamin Button  Fantasy      Warner Bros.
# 60   High School Musical 3: Senior Year   Comedy            Disney
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 41                50       1.983200                 38         $39.66   2011
# ...

# %%
df.sample(n=10,replace=True)
# Out:
#                                    Film    Genre  Lead Studio  \
# 56                          Just Wright   Comedy          Fox
# 14          The Twilight Saga: New Moon    Drama       Summit
# 50                   Life as We Know It   Comedy  Independent
# 37   Nick and Norah's Infinite Playlist   Comedy         Sony
# 10  Tyler Perry's Why Did I get Married  Romance  Independent
# 75                           27 Dresses   Comedy          Fox
# 2    You Will Meet a Tall Dark Stranger   Comedy  Independent
# 50                   Life as We Know It   Comedy  Independent
# 62                      Good Luck Chuck   Comedy    Lionsgate
# 2    You Will Meet a Tall Dark Stranger   Comedy  Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 56                58       1.797417                 45         $21.57   2010
# 14                78      14.196400                 27        $709.82   2009
# ...

# %%
df.sample(n=100,replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9340\3784905801.py in <module>
# ----> 1 df.sample(n=100,replace=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5444             weights = sample.preprocess_weights(self, weights, axis)
#    5445
# -> 5446         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5447         result = self.take(sampled_indices, axis=axis)
#    5448
#
# ~\anaconda3\lib\site-packages\pandas\core\sample.py in sample(obj_len, size, replace, weights, random_state)
#     148             raise ValueError("Invalid weights: weights sum to zero")
#     149
# --> 150     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151         np.intp, copy=False
#     152     )
# ...

# %%
df.sample(n=100,replace=True)
# Out:
#                            Film    Genre   Lead Studio  Audience score %  \
# 43            Midnight in Paris  Romence          Sony                84
# 71                    Beginners   Comedy   Independent                80
# 58             It's Complicated   Comedy     Universal                63
# 3                  When in Rome   Comedy        Disney                44
# 68                    Fireproof    Drama   Independent                51
# ..                          ...      ...           ...               ...
# 61  He's Just Not That Into You   Comedy  Warner Bros.                60
# 46                   Mamma Mia!   Comedy     Universal                76
# 49           Love & Other Drugs   Comedy           Fox                55
# 68                    Fireproof    Drama   Independent                51
# 27             Sex and the City   Comedy  Warner Bros.                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.sample(frac=.3)
# Out:
#                                    Film      Genre            Lead Studio  \
# 62                      Good Luck Chuck     Comedy              Lionsgate
# 53                            Leap Year     Comedy              Universal
# 49                   Love & Other Drugs     Comedy                    Fox
# 8                   Waiting For Forever    Romance            Independent
# 4                 What Happens in Vegas     Comedy                    Fox
# 58                     It's Complicated     Comedy              Universal
# 17               The Invention of Lying     Comedy           Warner Bros.
# 16                         The Proposal     Comedy                 Disney
# 6                                WALL-E  Animation                 Disney
# 36                      No Reservations     Comedy           Warner Bros.
# 28                          Remember Me      Drama                 Summit
# 20  The Curious Case of Benjamin Button    Fantasy           Warner Bros.
# ...

# %%
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.sort_values(by="Worldwide Gross", ascending=True)
# Out:
#                           Film    Genre            Lead Studio  \
# 8          Waiting For Forever  Romance            Independent
# 35           Not Easily Broken    Drama            Independent
# 15    The Time Traveler's Wife    Drama              Paramount
# 66  Ghosts of Girlfriends Past   Comedy           Warner Bros.
# 47               Made of Honor    Comdy                   Sony
# ..                         ...      ...                    ...
# 39        My Week with Marilyn    Drama  The Weinstein Company
# 74          A Dangerous Method    Drama            Independent
# 36             No Reservations   Comedy           Warner Bros.
# 55                     Killers   Action              Lionsgate
# 50          Life as We Know It   Comedy            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 8                 53       0.005000                  6          $0.03   2011
# ...

# %%
df.sort_values(by="Worldwide Gross", ascending=False)
# Out:
#                           Film    Genre            Lead Studio  \
# 50          Life as We Know It   Comedy            Independent
# 55                     Killers   Action              Lionsgate
# 36             No Reservations   Comedy           Warner Bros.
# 74          A Dangerous Method    Drama            Independent
# 39        My Week with Marilyn    Drama  The Weinstein Company
# ..                         ...      ...                    ...
# 47               Made of Honor    Comdy                   Sony
# 66  Ghosts of Girlfriends Past   Comedy           Warner Bros.
# 15    The Time Traveler's Wife    Drama              Paramount
# 35           Not Easily Broken    Drama            Independent
# 8          Waiting For Forever  Romance            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 50                62       2.530526                 28         $96.16   2010
# ...

# %%
df.sort_values(by=["Worldwide Gross","Genre"], ascending=False)
# Out:
#                           Film    Genre            Lead Studio  \
# 50          Life as We Know It   Comedy            Independent
# 55                     Killers   Action              Lionsgate
# 36             No Reservations   Comedy           Warner Bros.
# 74          A Dangerous Method    Drama            Independent
# 39        My Week with Marilyn    Drama  The Weinstein Company
# ..                         ...      ...                    ...
# 47               Made of Honor    Comdy                   Sony
# 66  Ghosts of Girlfriends Past   Comedy           Warner Bros.
# 15    The Time Traveler's Wife    Drama              Paramount
# 35           Not Easily Broken    Drama            Independent
# 8          Waiting For Forever  Romance            Independent
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 50                62       2.530526                 28         $96.16   2010
# ...

# %%
df.sort_values(by="Audience score %",ascending=False).head()
# Out:
#                     Film      Genre            Lead Studio  Audience score %  \
# 74    A Dangerous Method      Drama            Independent                89
# 6                 WALL-E  Animation                 Disney                89
# 22               Tangled  Animation                 Disney                88
# 39  My Week with Marilyn      Drama  The Weinstein Company                84
# 72   Across the Universe    romance            Independent                84
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 74       0.448645                 79          $8.97   2011
# 6        2.896019                 96        $521.28   2008
# 22       1.365692                 89        $355.01   2010
# 39       0.825800                 83          $8.26   2011
# 72       0.652603                 54         $29.37   2007

# %%
df.sort_values(by=["Audience score %","Film"],ascending=False).head()
# Out:
#                     Film      Genre            Lead Studio  Audience score %  \
# 6                 WALL-E  Animation                 Disney                89
# 74    A Dangerous Method      Drama            Independent                89
# 22               Tangled  Animation                 Disney                88
# 39  My Week with Marilyn      Drama  The Weinstein Company                84
# 43     Midnight in Paris    Romence                   Sony                84
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 6        2.896019                 96        $521.28   2008
# 74       0.448645                 79          $8.97   2011
# 22       1.365692                 89        $355.01   2010
# 39       0.825800                 83          $8.26   2011
# 43       8.744706                 93        $148.66   2011

# %% [markdown]
# #Data Frame slicing
# 1.loc
# 2.iloc
# 3.boolean/condition

# %%
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df[df["Genre"]=="Romance"]
# Out:
#                                    Film    Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno  Romance  The Weinstein Company
# 7                              Waitress  Romance            Independent
# 8                   Waiting For Forever  Romance            Independent
# 10  Tyler Perry's Why Did I get Married  Romance            Independent
# 11              Twilight: Breaking Dawn  Romance            Independent
# 12                             Twilight  Romance                 Summit
# 23                   Something Borrowed  Romance            Independent
# 31                      P.S. I Love You  Romance            Independent
# 34                              One Day  Romance            Independent
# 38                       New Year's Eve  Romance           Warner Bros.
# 40                     Music and Lyrics  Romance           Warner Bros.
# 41                          Monte Carlo  Romance       20th Century Fox
# ...

# %%
df[(df["Genre"]=="Romance") & (df["Year"]==2011)].sort_values(by="Worldwide Gross",ascending=False).head(3)
# Out:
#                        Film    Genre  Lead Studio  Audience score %  \
# 11  Twilight: Breaking Dawn  Romance  Independent                68
# 23       Something Borrowed  Romance  Independent                48
# 34                  One Day  Romance  Independent                54
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 11       6.383364                 26        $702.17   2011
# 23       1.719514                 15         $60.18   2011
# 34       3.682733                 37         $55.24   2011

# %%
df1=pd.read_csv("E:\e drive data\Datasets\Download CSV From Kaggle\Mumbai_restaurants.csv")
df1
# Out:
#      Unnamed: 0                             Name  Rating  \
# 0             0                  Huber And Holly     5.0
# 1             1                  Apna Food Court     5.0
# 2             2                         abCoffee     5.0
# 3             3  OG Juices - Cold Pressed Juices     4.9
# 4             4                      Spicy Mango     4.9
# ..          ...                              ...     ...
# 475         475                     Via Calcutta     4.0
# 476         476                      Rolls Mania     4.0
# 477         477           The Greedyman Pizzeria     4.0
# 478         478                    Malvani Touch     4.0
# 479         479                     Samosa Singh     4.0
#
#                                               Specials Delivery time  \
# 0                                  Ice Cream, Desserts       61 MINS
# 1                                 Chinese, Continental       45 MINS
# 2                                    Beverages, Bakery       41 MINS
# ...

# %%
df1["Cost"].min()
# Out:
# '₹100 FOR TWO'

# %%
df1["Cost"].max()
# Out:
# '₹900 FOR TWO'

# %%
import pandas as pd

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#df.loc[[index1,index2,...],[col_label1,col_label2,...]]
df.loc[[1,6,3],["gender","day","total_bill"]]
# Out:
#   gender  day  total_bill
# 1   Male  Sun       10.34
# 6   Male  Sun        8.77
# 3   Male  Sun       23.68

# %%
df.loc[[6],["day"]]
# Out:
#    day
# 6  Sun

# %%
#df.loc[start:end:step,start_col_label:end_col_label:step]
df.loc[0:3:1,"total_bill":"day":1]
# Out:
#    total_bill   tip  gender smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun

# %%
df.loc[0:14,"total_bill":"day"]
# Out:
#     total_bill   tip  gender smoker  day
# 0        16.99  1.01  Female     No  Sun
# 1        10.34  1.66    Male     No  Sun
# 2        21.01  3.50    Male     No  Sun
# 3        23.68  3.31    Male     No  Sun
# 4        24.59  3.61  Female     No  Sun
# 5        25.29  4.71    Male     No  Sun
# 6         8.77  2.00    Male     No  Sun
# 7        26.88  3.12    Male     No  Sun
# 8        15.04  1.96    Male     No  Sun
# 9        14.78  3.23    Male     No  Sun
# 10       10.27  1.71    Male     No  Sun
# 11       35.26  5.00  Female     No  Sun
# 12       15.42  1.57    Male     No  Sun
# 13       18.43  3.00    Male     No  Sun
# 14       14.83  3.02  Female     No  Sun

# %%
df.loc[0:14:2,"total_bill":"day":2]
# Out:
#     total_bill  gender  day
# 0        16.99  Female  Sun
# 2        21.01    Male  Sun
# 4        24.59  Female  Sun
# 6         8.77    Male  Sun
# 8        15.04    Male  Sun
# 10       10.27    Male  Sun
# 12       15.42    Male  Sun
# 14       14.83  Female  Sun

# %%
df.loc[:9,:"day"]
# Out:
#    total_bill   tip  gender smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun
# 4       24.59  3.61  Female     No  Sun
# 5       25.29  4.71    Male     No  Sun
# 6        8.77  2.00    Male     No  Sun
# 7       26.88  3.12    Male     No  Sun
# 8       15.04  1.96    Male     No  Sun
# 9       14.78  3.23    Male     No  Sun

# %%
df.loc[3:,"total_bill":]
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [241 rows x 7 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#df.iloc[[int_index1,int_index2,..],[col_index1,col_index2,...]]
df.iloc[[1,3,6,4],[0,2,4,6]]
# Out:
#    total_bill  gender  day  size
# 1       10.34    Male  Sun     3
# 3       23.68    Male  Sun     2
# 6        8.77    Male  Sun     2
# 4       24.59  Female  Sun     4

# %%
df.iloc[[3,5,8,2],[0,4,2]]
# Out:
#    total_bill  day gender
# 3       23.68  Sun   Male
# 5       25.29  Sun   Male
# 8       15.04  Sun   Male
# 2       21.01  Sun   Male

# %%
df.iloc[0:4:1,0:5:1]
# Out:
#    total_bill   tip  gender smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun

# %%
df.iloc[:6,:5]
# Out:
#    total_bill   tip  gender smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun
# 4       24.59  3.61  Female     No  Sun
# 5       25.29  4.71    Male     No  Sun

# %%
df.iloc[[0,-1],[0,-1]]
# Out:
#      total_bill  size
# 0         16.99     2
# 243       18.78     2

# %%
df.iloc[10:,2:]
# Out:
#      gender smoker   day    time  size
# 10     Male     No   Sun  Dinner     2
# 11   Female     No   Sun  Dinner     4
# 12     Male     No   Sun  Dinner     2
# 13     Male     No   Sun  Dinner     4
# 14   Female     No   Sun  Dinner     2
# ..      ...    ...   ...     ...   ...
# 239    Male     No   Sat  Dinner     3
# 240  Female    Yes   Sat  Dinner     2
# 241    Male    Yes   Sat  Dinner     2
# 242    Male     No   Sat  Dinner     2
# 243  Female     No  Thur  Dinner     2
#
# [234 rows x 5 columns]

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/movies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.iloc[[0:],[1,3,4]]
# Out:
#   File "C:\Users\india\AppData\Local\Temp\ipykernel_8984\3442599492.py", line 1
#     df.iloc[[0:],[1,3,4]]
#               ^
# SyntaxError: invalid syntax

# %%
df.iloc[0:,[1,3,4]]
# Out:
#                                                title   category  duration
# 0                           The Shawshank Redemption      Crime       142
# 1                                      The Godfather      Crime       175
# 2                             The Godfather: Part II      Crime       200
# 3                                    The Dark Knight     Action       152
# 4                                       Pulp Fiction      Crime       154
# ..                                               ...        ...       ...
# 974                                          Tootsie     Comedy       116
# 975                      Back to the Future Part III  Adventure       118
# 976  Master and Commander: The Far Side of the World     Action       138
# 977                                      Poltergeist     Horror       114
# 978                                      Wall Street      Crime       126
#
# [979 rows x 3 columns]

# %%
df[["title","category","duration"]]
# Out:
#                                                title   category  duration
# 0                           The Shawshank Redemption      Crime       142
# 1                                      The Godfather      Crime       175
# 2                             The Godfather: Part II      Crime       200
# 3                                    The Dark Knight     Action       152
# 4                                       Pulp Fiction      Crime       154
# ..                                               ...        ...       ...
# 974                                          Tootsie     Comedy       116
# 975                      Back to the Future Part III  Adventure       118
# 976  Master and Commander: The Far Side of the World     Action       138
# 977                                      Poltergeist     Horror       114
# 978                                      Wall Street      Crime       126
#
# [979 rows x 3 columns]

# %%
df.iloc[0:,[0,-1]]
# Out:
#      star_rating                                        actors_list
# 0            9.3  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1            9.2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2            9.1  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3            9.0  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4            8.9  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..           ...                                                ...
# 974          7.4  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975          7.4  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976          7.4  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977          7.4  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978          7.4  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 2 columns]

# %%
#comedy 
df[df.category=="Comedy"]
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating category  duration  \
# 25           PG-13   Comedy       116
# 29          PASSED   Comedy        87
# ...

# %%
#avarage duration of comedy movies
df[df.category=="Comedy"].duration.mean()
# Out:
# 107.6025641025641

# %%
#avarage rating of comedy movies
df[df.category=="Comedy"].star_rating.mean()
# Out:
# 7.82243589743591

# %%
#all data except last column
df.iloc[:,0:-1]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
#all data except first column
df.iloc[:,1:]
# Out:
#                                                title content_rating  \
# 0                           The Shawshank Redemption              R
# 1                                      The Godfather              R
# 2                             The Godfather: Part II              R
# 3                                    The Dark Knight          PG-13
# 4                                       Pulp Fiction              R
# ..                                               ...            ...
# 974                                          Tootsie             PG
# 975                      Back to the Future Part III             PG
# 976  Master and Commander: The Far Side of the World          PG-13
# 977                                      Poltergeist             PG
# 978                                      Wall Street              R
#
#       category  duration                                        actors_list
# ...

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#only float values
df.select_dtypes(include=float)
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df.select_dtypes(exclude=int)
# Out:
#      total_bill   tip  gender smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
df.select_dtypes(exclude=float).head()
# Out:
#    gender smoker  day    time  size
# 0  Female     No  Sun  Dinner     2
# 1    Male     No  Sun  Dinner     3
# 2    Male     No  Sun  Dinner     3
# 3    Male     No  Sun  Dinner     2
# 4  Female     No  Sun  Dinner     4

# %%
#only float and int
df.select_dtypes(include=[float,int]).head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
#only float and int
df.select_dtypes(include=['float','int']).head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
#only string
df.select_dtypes(include=object)
# Out:
#      gender smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include="all")
# Out:
#         total_bill         tip gender smoker  day    time        size
# count   244.000000  244.000000    244    244  244     244  244.000000
# unique         NaN         NaN      2      2    4       2         NaN
# top            NaN         NaN   Male     No  Sat  Dinner         NaN
# freq           NaN         NaN    157    151   87     176         NaN
# mean     19.785943    2.998279    NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638    NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000    NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000    NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000    NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500    NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000    NaN    NaN  NaN     NaN    6.000000

# %%
df.describe(include="object")
# Out:
#        gender smoker  day    time
# count     244    244  244     244
# unique      2      2    4       2
# top      Male     No  Sat  Dinner
# freq      157    151   87     176

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#groupby
df.groupby(by="gender").total_bill.sum()
# Out:
# gender
# Female    1570.95
# Male      3256.82
# Name: total_bill, dtype: float64

# %%
df[df.gender=='Male'].total_bill.sum()
# Out:
# 3256.8199999999997

# %%
df.groupby(by="gender").smoker.count()
# Out:
# gender
# Female     87
# Male      157
# Name: smoker, dtype: int64

# %%
#day wise groupby on total_bill
df.groupby(by="day").total_bill.sum()
# Out:
# day
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33
# Name: total_bill, dtype: float64

# %%
df[df.day=="Sun"].groupby(by="gender").smoker.count()
# Out:
# gender
# Female    18
# Male      58
# Name: smoker, dtype: int64

# %%
df[df.day=="Fri"].groupby(by="gender").gender.count()
# Out:
# gender
# Female     9
# Male      10
# Name: gender, dtype: int64

# %%
#total coutomer day wise
df.groupby(by="day").gender.count()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: gender, dtype: int64

# %%
df.groupby(by="day").total_bill.agg(["sum","count"])
# Out:
#           sum  count
# day
# Fri    325.88     19
# Sat   1778.40     87
# Sun   1627.16     76
# Thur  1096.33     62

# %%
df.groupby(by="day").total_bill.agg(["count","sum"])
# Out:
#       count      sum
# day
# Fri      19   325.88
# Sat      87  1778.40
# Sun      76  1627.16
# Thur     62  1096.33

# %%
df[df.gender=="Male"].groupby(by="day").total_bill.agg(["count","sum"])
# Out:
#       count      sum
# day
# Fri      10   198.57
# Sat      59  1227.35
# Sun      58  1269.46
# Thur     30   561.44

# %%
df.groupby(by="day").total_bill.describe()
# Out:
#       count       mean       std   min      25%    50%      75%    max
# day
# Fri    19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat    87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun    76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
# Thur   62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11

# %%
df.groupby(by=["day","time"]).total_bill.agg(["count","sum"])
# Out:
#              count      sum
# day  time
# Fri  Dinner     12   235.96
#      Lunch       7    89.92
# Sat  Dinner     87  1778.40
# Sun  Dinner     76  1627.16
# Thur Dinner      1    18.78
#      Lunch      61  1077.55

# %%
df.groupby(by=["day","gender"]).total_bill.agg(["count","sum"])
# Out:
#              count      sum
# day  gender
# Fri  Female      9   127.31
#      Male       10   198.57
# Sat  Female     28   551.05
#      Male       59  1227.35
# Sun  Female     18   357.70
#      Male       58  1269.46
# Thur Female     32   534.89
#      Male       30   561.44

# %%
df.groupby(by=["day","gender","time"]).total_bill.agg(["count","sum"])
# Out:
#                     count      sum
# day  gender time
# Fri  Female Dinner      5    71.55
#             Lunch       4    55.76
#      Male   Dinner      7   164.41
#             Lunch       3    34.16
# Sat  Female Dinner     28   551.05
#      Male   Dinner     59  1227.35
# Sun  Female Dinner     18   357.70
#      Male   Dinner     58  1269.46
# Thur Female Dinner      1    18.78
#             Lunch      31   516.11
#      Male   Lunch      30   561.44

# %%
import pandas as pd

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(by=["day","time"]).tip.agg(["sum","max","min"])
# Out:
#                 sum    max   min
# day  time
# Fri  Dinner   35.28   4.73  1.00
#      Lunch    16.68   3.48  1.58
# Sat  Dinner  260.40  10.00  1.00
# Sun  Dinner  247.39   6.50  1.01
# Thur Dinner    3.00   3.00  3.00
#      Lunch   168.83   6.70  1.25

# %%
df[df.day=="Sat"].groupby(by=["gender","time"],).gender.count()
# Out:
# gender  time
# Female  Dinner    28
# Male    Dinner    59
# Name: gender, dtype: int64

# %%
df.groupby(by=["day","time","gender"]).gender.agg(["count"])
# Out:
#                     count
# day  time   gender
# Fri  Dinner Female      5
#             Male        7
#      Lunch  Female      4
#             Male        3
# Sat  Dinner Female     28
#             Male       59
# Sun  Dinner Female     18
#             Male       58
# Thur Dinner Female      1
#      Lunch  Female     31
#             Male       30

# %%
df.pivot_table(index="day",values="total_bill",aggfunc="sum")
# Out:
#       total_bill
# day
# Fri       325.88
# Sat      1778.40
# Sun      1627.16
# Thur     1096.33

# %%
df.groupby(by="day").total_bill.agg(["sum"])
# Out:
#           sum
# day
# Fri    325.88
# Sat   1778.40
# Sun   1627.16
# Thur  1096.33

# %%
df.pivot_table(index="day",values="total_bill",aggfunc=["sum","mean"])
# Out:
#             sum       mean
#      total_bill total_bill
# day
# Fri      325.88  17.151579
# Sat     1778.40  20.441379
# Sun     1627.16  21.410000
# Thur    1096.33  17.682742

# %%
df.pivot_table(index="day",values="total_bill",aggfunc=["sum"])
# Out:
#             sum
#      total_bill
# day
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Thur    1096.33

# %%
df.groupby(by=["day","time","gender"]).gender.agg(["count"])
#df.pivot_table(index=["day","time","gender"],values="gender",aggfunc="count")
# Out:
#                     count
# day  time   gender
# Fri  Dinner Female      5
#             Male        7
#      Lunch  Female      4
#             Male        3
# Sat  Dinner Female     28
#             Male       59
# Sun  Dinner Female     18
#             Male       58
# Thur Dinner Female      1
#      Lunch  Female     31
#             Male       30

# %%
df.pivot_table(index=["day","time"],values="total_bill",aggfunc=["sum","count"])
# Out:
#                    sum      count
#             total_bill total_bill
# day  time
# Fri  Dinner     235.96         12
#      Lunch       89.92          7
# Sat  Dinner    1778.40         87
# Sun  Dinner    1627.16         76
# Thur Dinner      18.78          1
#      Lunch     1077.55         61

# %%
df.pivot_table(index=["day","time"],values="gender",aggfunc=["count"])
# Out:
#              count
#             gender
# day  time
# Fri  Dinner     12
#      Lunch       7
# Sat  Dinner     87
# Sun  Dinner     76
# Thur Dinner      1
#      Lunch      61

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby(by=["day","time"]).(total_bill,tip).agg(["max","min"])
# Out:
#   File "C:\Users\india\AppData\Local\Temp\ipykernel_11340\408682599.py", line 1
#     df.groupby(by=["day","time"]).(total_bill,tip).agg(["max","min"])
#                                   ^
# SyntaxError: invalid syntax

# %%
res_df=df.pivot_table(index=["day","time"],values=["total_bill","tip"],aggfunc=["max","min"])

# %%
res_df.to_excel("E:/data.xlsx")

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#correlation
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import pandas as pd

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Survived==1].shape[0]
# Out:
# 342

# %%
df[df.Survived==0].shape[0]
# Out:
# 549

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Survived.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
print("Survived% =",549/891)
# Out:
# Survived% = 0.6161616161616161

# %%
print("Not Survived% =",342/891)
# Out:
# Not Survived% = 0.3838383838383838

# %%
df.gender.value_counts()
# Out:
# male      577
# female    314
# Name: gender, dtype: int64

# %%
#survived male
df[(df.gender=="male") & (df.Survived==1)].shape[0]
# Out:
# 109

# %%
df[(df.gender=="female") & (df.Survived==1)].shape[0]
# Out:
# 233

# %%
109/577
# Out:
# 0.18890814558058924

# %%
233/314
# Out:
# 0.7420382165605095

# %%
df[df.Age>60].shape[0]
# Out:
# 22

# %%
df[(df.Age>60) & (df.Survived==1)].shape[0]
# Out:
# 5

# %%
df[(df.Age>60) & (df.Survived==1) & (df.gender=="female")].shape[0]
# Out:
# 3

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[(df.Survived==1) & (df.Pclass==1)].shape[0]
# Out:
# 136

# %%
df[(df.Survived==1) & (df.Pclass==2)].shape[0]
# Out:
# 87

# %%
df[(df.Survived==1) & (df.Pclass==3)].shape[0]
# Out:
# 119

# %%
136/216
# Out:
# 0.6296296296296297

# %%
87/184
# Out:
# 0.47282608695652173

# %%
119/491
# Out:
# 0.24236252545824846

# %%
df[(df.Survived==1) & (df.Pclass==1)].groupby(by="gender").gender.count()
# Out:
# gender
# female    91
# male      45
# Name: gender, dtype: int64

# %%
91/136
# Out:
# 0.6691176470588235

# %%
45/136
# Out:
# 0.33088235294117646

# %%
df[df.Age<10].shape[0]
# Out:
# 62

# %%
df[(df.Survived==1)&(df.Age<10)].shape[0]
# Out:
# 38

# %%
38/62
# Out:
# 0.6129032258064516

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df.SibSp==0].shape
# Out:
# (608, 12)

# %%
df[(df.SibSp==0) & (df.Parch==0)].shape
# Out:
# (537, 12)

# %%
df[(df.Survived==1) & (df.SibSp==0) & (df.Parch==0)].shape
# Out:
# (163, 12)

# %%
163/537
# Out:
# 0.30353817504655495

# %%
df[(df.Survived==1) & (df.SibSp==0) & (df.Parch==0)].groupby(by="gender").gender.count()
# Out:
# gender
# female    99
# male      64
# Name: gender, dtype: int64

# %%
99/163
# Out:
# 0.6073619631901841

# %%
64/163
# Out:
# 0.39263803680981596

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values(by="Fare",ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#      gender   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
df=pd.read_excel("E:/dataset/dataset/Sample - Superstore.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1          2  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 2          3  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 3          4  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4          5  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.Sales.sum()
# Out:
# 2297200.8603000003

# %%
df.Profit.sum()
# Out:
# 286397.0216999999

# %%
286397/2297200
# Out:
# 0.1246722096465262

# %%
df.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df.Category.value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df.groupby(by="Category").Profit.agg(["sum"])
# Out:
#                          sum
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
df.pivot_table(index="Category",values="Profit",aggfunc=["sum"])
# Out:
#                          sum
#                       Profit
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
df.pivot_table(index="Category",values=["Profit","Sales"],aggfunc=["sum"])
# Out:
#                          sum
#                       Profit        Sales
# Category
# Furniture         18451.2728  741999.7953
# Office Supplies  122490.8008  719047.0320
# Technology       145454.9481  836154.0330

# %%
df.pivot_table(index="Category",values=["Profit","Sales"],aggfunc=["sum","count"])
# Out:
#                          sum               count
#                       Profit        Sales Profit Sales
# Category
# Furniture         18451.2728  741999.7953   2121  2121
# Office Supplies  122490.8008  719047.0320   6026  6026
# Technology       145454.9481  836154.0330   1847  1847

# %%
df.pivot_table(index="Region",values=["Profit","Sales"],aggfunc=["sum"])
# Out:
#                  sum
#               Profit        Sales
# Region
# Central   39706.3625  501239.8908
# East      91522.7800  678781.2400
# South     46749.4303  391721.9050
# West     108418.4489  725457.8245

# %%
df.pivot_table(index=["Region","Category"],values=["Sales","Profit"],aggfunc=["sum"])
# Out:
#                                 sum
#                              Profit        Sales
# Region  Category
# Central Furniture        -2871.0494  163797.1638
#         Office Supplies   8879.9799  167026.4150
#         Technology       33697.4320  170416.3120
# East    Furniture         3046.1658  208291.2040
#         Office Supplies  41014.5791  205516.0550
#         Technology       47462.0351  264973.9810
# South   Furniture         6771.2061  117298.6840
#         Office Supplies  19986.3928  125651.3130
#         Technology       19991.8314  148771.9080
# West    Furniture        11504.9503  252612.7435
#         Office Supplies  52609.8490  220853.2490
#         Technology       44303.6496  251991.8320

# %%
df.pivot_table(index=["Category","Region"],values=["Sales","Profit"],aggfunc=["sum"])
# Out:
#                                 sum
#                              Profit        Sales
# Category        Region
# Furniture       Central  -2871.0494  163797.1638
#                 East      3046.1658  208291.2040
#                 South     6771.2061  117298.6840
#                 West     11504.9503  252612.7435
# Office Supplies Central   8879.9799  167026.4150
#                 East     41014.5791  205516.0550
#                 South    19986.3928  125651.3130
#                 West     52609.8490  220853.2490
# Technology      Central  33697.4320  170416.3120
#                 East     47462.0351  264973.9810
#                 South    19991.8314  148771.9080
#                 West     44303.6496  251991.8320

# %%
df.pivot_table(index="City",values=["Profit","Sales"],aggfunc=["sum"])
# Out:
#                    sum
#                 Profit     Sales
# City
# Aberdeen        6.6300    25.500
# Abilene        -3.7584     1.392
# Akron        -186.6356  2729.986
# Albuquerque   634.0881  2220.160
# Alexandria    318.6183  5519.570
# ...                ...       ...
# Woonsocket     78.6791   195.550
# Yonkers      2767.7557  7657.666
# York         -102.1692   817.978
# Yucaipa        13.2080    50.800
# Yuma         -465.9909   840.865
#
# [531 rows x 2 columns]

# %%
df.pivot_table(index="City",values=["Profit","Sales"],aggfunc=["sum"])
# Out:
#                    sum
#                 Profit     Sales
# City
# Aberdeen        6.6300    25.500
# Abilene        -3.7584     1.392
# Akron        -186.6356  2729.986
# Albuquerque   634.0881  2220.160
# Alexandria    318.6183  5519.570
# ...                ...       ...
# Woonsocket     78.6791   195.550
# Yonkers      2767.7557  7657.666
# York         -102.1692   817.978
# Yucaipa        13.2080    50.800
# Yuma         -465.9909   840.865
#
# [531 rows x 2 columns]

# %%
df[df.Profit<0].City
# Out:
# 3       Fort Lauderdale
# 14           Fort Worth
# 15           Fort Worth
# 23         Philadelphia
# 27         Philadelphia
#              ...
# 9920              Bryan
# 9921              Akron
# 9931     San Bernardino
# 9937        Los Angeles
# 9962            Houston
# Name: City, Length: 1871, dtype: object

# %%
profit_city=df.pivot_table(index="City",values="Profit",aggfunc=["sum"])

# %%
profit_city[profit_city.values<0]
# Out:
#                 sum
#              Profit
# City
# Abilene     -3.7584
# Akron     -186.6356
# Allen      -39.8775
# Allentown -226.4504
# Altoona     -1.1835
# ...             ...
# Waco      -520.1034
# Wheeling  -107.3962
# Wilson     -14.3360
# York      -102.1692
# Yuma      -465.9909
#
# [116 rows x 1 columns]

# %%
df[df.Profit<0].pivot_table(index="City",values="Profit",aggfunc=["sum"])
# Out:
#                   sum
#                Profit
# City
# Abilene       -3.7584
# Akron       -359.5675
# Albuquerque   -5.6943
# Allen        -45.2559
# Allentown   -249.4556
# ...               ...
# Wilson       -38.1948
# Woodstock    -25.7959
# Yonkers     -264.9208
# York        -125.9434
# Yuma        -515.8728
#
# [229 rows x 1 columns]

# %%
df.pivot_table(index=["Category","Sub-Category"],values=["Profit","Sales"],aggfunc=["sum"])
# Out:
#                                      sum
#                                   Profit        Sales
# Category        Sub-Category
# Furniture       Bookcases     -3472.5560  114879.9963
#                 Chairs        26590.1663  328449.1030
#                 Furnishings   13059.1436   91705.1640
#                 Tables       -17725.4811  206965.5320
# Office Supplies Appliances    18138.0054  107532.1610
#                 Art            6527.7870   27118.7920
#                 Binders       30221.7633  203412.7330
#                 Envelopes      6964.1767   16476.4020
#                 Fasteners       949.5182    3024.2800
#                 Labels         5546.2540   12486.3120
#                 Paper         34053.5693   78479.2060
#                 Storage       21278.8264  223843.6080
#                 Supplies      -1189.0995   46673.5380
# Technology      Accessories   41936.6357  167380.3180
#                 Copiers       55617.8249  149528.0300
# ...

# %%
df=pd.read_excel("E:/dataset/dataset/Sample - Superstore.xls")
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1          2  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 2          3  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 3          4  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4          5  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df[df.Profit>100].shape
# Out:
# (890, 21)

# %%
df[df.Profit<0].shape
# Out:
# (1871, 21)

# %%
df[df["Order Date"]>"2020-1-1"].shape
# Out:
# (5899, 21)

# %%
df[(df["Order Date"]>"2019-1-1") & (df["Order Date"]<"2020-12-31")].shape
# Out:
# (4682, 21)

# %%
df[df["Order Date"]=="2020-07-25"].shape
# Out:
# (19, 21)

# %%
df[df["Order Date"]==2020-7-25]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[(df["Order Date"]>"2018-1-1") & (df["Order Date"]<="2018-12-31")].shape
# Out:
# (1993, 24)

# %%
df[(df["Order Date"]>"2019-1-1") & (df["Order Date"]<="2019-12-31")].shape
# Out:
# (2102, 24)

# %%
df[(df["Order Date"]>"2020-1-1") & (df["Order Date"]<="2020-12-31")].shape
# Out:
# (2587, 24)

# %%
df[(df["Order Date"]>"2021-1-1") & (df["Order Date"]<="2021-12-31")].shape
# Out:
# (3302, 24)

# %%
#df["Order Date"].dt.year
#df["Order Date"].dt.day
#df["Order Date"].dt.month
#df["Order Date"].dt.month_name()
df["Order Date"].dt.day_name()
# Out:
# 0        Sunday
# 1        Sunday
# 2        Friday
# 3        Friday
# 4        Friday
#          ...
# 9989     Sunday
# 9990     Friday
# 9991     Friday
# 9992     Friday
# 9993    Tuesday
# Name: Order Date, Length: 9994, dtype: object

# %%
aa=pd.DataFrame({"revenue":[100,200,300,400,350],"budget":[75,150,200,240,250]})
aa
# Out:
#    revenue  budget
# 0      100      75
# 1      200     150
# 2      300     200
# 3      400     240
# 4      350     250

# %%
aa["profit"]=aa.revenue-aa.budget

# %%
aa
# Out:
#    revenue  budget  profit
# 0      100      75      25
# 1      200     150      50
# 2      300     200     100
# 3      400     240     160
# 4      350     250     100

# %%
aa["max"]=range(30,40,2)

# %%
aa
# Out:
#    revenue  budget  profit  max
# 0      100      75      25   30
# 1      200     150      50   32
# 2      300     200     100   34
# 3      400     240     160   36
# 4      350     250     100   38

# %%
aa["random"]=[1,2,3,4,5]

# %%
aa
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25   30       1
# 1      200     150      50   32       2
# 2      300     200     100   34       3
# 3      400     240     160   36       4
# 4      350     250     100   38       5

# %%
aa["random_1"]=(1,4,3,8,5)

# %%
aa
# Out:
#    revenue  budget  profit  max  random  random_1
# 0      100      75      25   30       1         1
# 1      200     150      50   32       2         4
# 2      300     200     100   34       3         3
# 3      400     240     160   36       4         8
# 4      350     250     100   38       5         5

# %%
aa.iat[2,1]=250

# %%
aa
# Out:
#    revenue  budget  profit  max  random  random_1
# 0      100      75      25   30       1         1
# 1      200     150      50   32       2         4
# 2      300     250     100   34       3         3
# 3      400     240     160   36       4         8
# 4      350     250     100   38       5         5

# %%
aa["max"]=range(0,5)

# %%
aa
# Out:
#    revenue  budget  profit  max  random  random_1
# 0      100      75      25    0       1         1
# 1      200     150      50    1       2         4
# 2      300     250     100    2       3         3
# 3      400     240     160    3       4         8
# 4      350     250     100    4       5         5

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df["year"]=df["Order Date"].dt.year
df["month"]=df["Order Date"].dt.month
df["day"]=df["Order Date"].dt.day_name()

# %%
df

# %%
df.year.value_counts()

# %%
df.groupby(by="year").Profit.agg(["sum","count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\498010849.py in <module>
# ----> 1 df.groupby(by="year").Profit.agg(["sum","count"])
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index="year",values="Profit",aggfunc=["sum","count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\3921006898.py in <module>
# ----> 1 df.pivot_table(index="year",values="Profit",aggfunc=["sum","count"])
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index=["year","Region"],values="Profit",aggfunc=["sum","count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\1084777699.py in <module>
# ----> 1 df.pivot_table(index=["year","Region"],values="Profit",aggfunc=["sum","count"])
#
# NameError: name 'df' is not defined

# %%
 df.pivot_table(index="month",values="Sales",aggfunc=["sum","count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\411313108.py in <module>
# ----> 1 df.pivot_table(index="month",values="Sales",aggfunc=["sum","count"])
#
# NameError: name 'df' is not defined

# %%
df.pivot_table(index=["month","year"],values="Sales",aggfunc=["sum","count"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\3038573891.py in <module>
# ----> 1 df.pivot_table(index=["month","year"],values="Sales",aggfunc=["sum","count"])
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/ufo.csv")
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
df["seen_date"]=pd.DatetimeIndex(df["Time"])

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time           seen_date
# 0        6/1/1930 22:00 1930-06-01 22:00:00
# 1       6/30/1930 20:00 1930-06-30 20:00:00
# 2       2/15/1931 14:00 1931-02-15 14:00:00
# ...

# %%
df["Time"]=df["Time"].astype("datetime64")

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time           seen_date
# 0     1930-06-01 22:00:00 1930-06-01 22:00:00
# 1     1930-06-30 20:00:00 1930-06-30 20:00:00
# ...

# %%
df.drop("seen_date",axis=1)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time           seen_date
# 0     1930-06-01 22:00:00 1930-06-01 22:00:00
# 1     1930-06-30 20:00:00 1930-06-30 20:00:00
# ...

# %%
df.drop("seen_date",axis=1,inplace=True)

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
df.drop(["Colors Reported","Shape Reported"],axis=1,inplace=True)

# %%
df
# Out:
#                        City State                Time
# 0                    Ithaca    NY 1930-06-01 22:00:00
# 1               Willingboro    NJ 1930-06-30 20:00:00
# 2                   Holyoke    CO 1931-02-15 14:00:00
# 3                   Abilene    KS 1931-06-01 13:00:00
# 4      New York Worlds Fair    NY 1933-04-18 19:00:00
# ...                     ...   ...                 ...
# 18236            Grant Park    IL 2000-12-31 23:00:00
# 18237           Spirit Lake    IA 2000-12-31 23:00:00
# 18238           Eagle River    WI 2000-12-31 23:45:00
# 18239           Eagle River    WI 2000-12-31 23:45:00
# 18240                  Ybor    FL 2000-12-31 23:59:00
#
# [18241 rows x 3 columns]

# %%
aa
# Out:
#    revenue  budget  profit  max  random  random_1
# 0      100      75      25    0       1         1
# 1      200     150      50    1       2         4
# 2      300     250     100    2       3         3
# 3      400     240     160    3       4         8
# 4      350     250     100    4       5         5

# %%
aa.drop("random_1",axis=1)
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25    0       1
# 1      200     150      50    1       2
# 2      300     250     100    2       3
# 3      400     240     160    3       4
# 4      350     250     100    4       5

# %%
aa.drop("random_1",axis=1,inplace=True)

# %%
aa
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25    0       1
# 1      200     150      50    1       2
# 2      300     250     100    2       3
# 3      400     240     160    3       4
# 4      350     250     100    4       5

# %%
aa.drop(1,axis=0)
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25    0       1
# 2      300     250     100    2       3
# 3      400     240     160    3       4
# 4      350     250     100    4       5

# %%
aa.drop(3,axis=0,inplace=True)

# %%
aa
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25    0       1
# 2      300     250     100    2       3
# 4      350     250     100    4       5

# %%
aa.drop(["max","random"],axis=1)
# Out:
#    revenue  budget  profit
# 0      100      75      25
# 2      300     250     100
# 4      350     250     100

# %%
aa
# Out:
#    revenue  budget  profit  max  random
# 0      100      75      25    0       1
# 2      300     250     100    2       3
# 4      350     250     100    4       5

# %%
aa.drop(columns=["max","random"],inplace=True)

# %%
aa
# Out:
#    revenue  budget  profit
# 0      100      75      25
# 2      300     250     100
# 4      350     250     100

# %%
aa.drop(2,inplace=True)

# %%
aa
# Out:
#    revenue  budget  profit
# 0      100      75      25
# 4      350     250     100

# %%
df=pd.read_csv("E:/dataset/dataset/analysis/movies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   category  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df.category=="Crime"].shape
# Out:
# (124, 6)

# %%
df.filter(like="s")
# Out:
#      star_rating                                        actors_list
# 0            9.3  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1            9.2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2            9.1  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3            9.0  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4            8.9  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..           ...                                                ...
# 974          7.4  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975          7.4  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976          7.4  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977          7.4  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978          7.4  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 2 columns]

# %%
df[df.actors_list.str.contains("amir")]
# Out:
#      star_rating                              title content_rating   category  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 239          8.1      Elite Squad: The Enemy Within        UNRATED     Action
# 261          8.1                        Elite Squad              R     Action
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# ...

# %%
df[df.actors_list.str.contains("aamir",case=False)]
# Out:
#      star_rating                              title content_rating   category  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
import pandas as pd

# %%
df=pd.read_csv("e:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
pd.crosstab(df.day,df.time)
# Out:
# time  Dinner  Lunch
# day
# Fri       12      7
# Sat       87      0
# Sun       76      0
# Thur       1     61

# %%
pd.crosstab(df.gender,df.time)
# Out:
# time    Dinner  Lunch
# gender
# Female      52     35
# Male       124     33

# %%
pd.crosstab([df.gender,df.day],df.time)
# Out:
# time         Dinner  Lunch
# gender day
# Female Fri        5      4
#        Sat       28      0
#        Sun       18      0
#        Thur       1     31
# Male   Fri        7      3
#        Sat       59      0
#        Sun       58      0
#        Thur       0     30
