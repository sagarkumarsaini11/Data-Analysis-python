# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("e:/dataset/dataset/analysis/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#plt.subplot(r,c)
plt.subplot(2,2,1)
plt.hist(df.Age,edgecolor="k")

plt.subplot(2,2,2)
df.gender.value_counts().plot.bar()

plt.show()

# %%
plt.subplot(2,2,1)
plt.hist(df.Age,edgecolor="k")

plt.subplot(2,2,4)
df.gender.value_counts().plot.bar()

plt.show()

# %%
plt.figure(figsize=(6,2))
plt.subplot(1,2,1)
plt.hist(df.Age,edgecolor="k")
plt.title("Age Distribution")

plt.subplot(1,2,2)
df.gender.value_counts().plot.bar()
plt.title("Gender Count")

#plt.show()
plt.savefig("E:\\e drive data\\Download/Titanic_analysis.jpeg")

# %%
plt.figure(figsize=(5,3))
df.gender.value_counts().plot.bar()
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,3))
sns.countplot(x="gender",data=df)
plt.show()

# %%
df=pd.read_csv("e:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(5,3))
sns.countplot(x="day",data=df)
plt.xlabel("Day")

plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df.day)
plt.xlabel("Day")

plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df.day,order=["Thur","Fri","Sat","Sun"])
#plt.xlabel("Day")

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="day",data=df,order=["Thur","Fri","Sat","Sun"],hue="time")

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="day",data=df,order=["Thur","Fri","Sat","Sun"],hue="gender")

plt.show()

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="total_bill",y="tip",data=df,hue="gender",style="time")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x="total_bill",y="tip",data=df,hue="gender",style="day")
plt.show()

# %%
df=pd.read_csv("E:/dataset/dataset/regression/salary_1_variable.csv")
sns.lineplot(x="YearsExperience",y="Salary",data=df)
plt.show()

# %%
import pandas as pd
df=pd.read_csv("e:/dataset/dataset/analysis/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x="total_bill",y="tip",data=df) #combination of scatter and histogram
plt.show()

# %%
sns.pairplot(data=df) #draw histogram and scatter charts for each posiable pair of numeric cols
plt.show()

# %%
sns.boxplot(x="total_bill",data=df)
plt.show()

# %%
sns.boxplot(x="total_bill",y="gender",data=df)
plt.show()

# %%
sns.boxplot(x="total_bill",y="day",data=df)
plt.show()

# %%
sns.boxplot(y="total_bill",x="gender",data=df)
plt.show()

# %%
sns.boxplot(y="total_bill",data=df)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
matrix=np.random.randint(30,100,(5,4))
matrix
# Out:
# array([[77, 34, 61, 37],
#        [49, 32, 55, 47],
#        [35, 59, 44, 91],
#        [34, 40, 66, 87],
#        [61, 96, 55, 35]])

# %%
sns.heatmap(matrix)
plt.show()

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
plt.show()
