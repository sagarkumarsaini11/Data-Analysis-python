# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings;warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the dataset

# %%
df=pd.read_csv("E:\dataset\Kaggle _dataset\Analysis\shopping_trends.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ### Checking the shape of the Dataset

# %%
df.shape
# Out:
# (3900, 19)

# %% [markdown]
# ### Checking the number of Columns in the Dataset

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ### Information about the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ### Checking if there are any null values present in the dataset or not

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ### Checking if there are any duplicate values present in the dataset or not

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.Gender.value_counts())
plt.figure(figsize=(10,4))
ax=df.Gender.value_counts().plot.bar( rot = 0)
plt.xlabel("Employee type",c="r")
plt.ylabel("no. of occurrences",c="r")
plt.show()
# Out:
# Gender
# Male      2652
# Female    1248
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
explode=(0,0.1)
df.Gender.value_counts().plot.pie(explode=explode,autopct = '%1.1f%%')
plt.ylabel("Gender",c="darkgreen")
#plt.legend(labels =("male","female"),loc='upper right')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,5))
ax.hist(df.Age,bins=25,histtype='bar',edgecolor="k",alpha=0.8,color="skyblue",density=True)
df["Age"].plot(kind="kde",c="r",ax=ax)

ax.set_xlabel("Age",size=12)
ax.set_ylabel("count/Density",size=12)
ax.set_title("Age Distribution with histogram and Density",c="#2E4053")
plt.legend(["Age","Density"])
plt.show()

# %%
df.Category.value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,6))
ax=df.Category.value_counts()
plt.bar(x=ax.index,height=ax.values,color=(["#EC7063",'#D2B4DE','#73C6B6','#F9E79F']),width=0.6)
for x,y in zip(ax.index,ax.values):
    plt.text(x,y+6,y)
plt.xlabel("Category Type",c="r",size=15)
plt.ylabel("no. of occurrences",c="r",size=15)
plt.show()

# %%
s=df.Category.value_counts()
plt.figure(figsize=(8,4))
plt.pie(x=s.values,labels=s.index,explode=(0,0,0,0.1),autopct = '%1.1f%%')
plt.axis("equal")
plt.xlabel('Gender',labelpad=20,c="#2F0F5D")
plt.legend(labels=s.index,loc ="best")
plt.show()

# %%
plt.figure(figsize=(16,7))
df["Item Purchased"].value_counts().sort_values(ascending=True).plot(kind="barh",color=sns.color_palette("tab20"),edgecolor="k")
plt.title("Item Purchased\n",fontsize=16,c="#0C090A")
plt.xlabel("\nNumber of Occurrences",fontsize=16)
plt.ylabel("Item Purchased",fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.Location.value_counts()
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Virginia          77
# Ohio              77
# Tennessee         77
# Texas             77
# Maine             77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Alaska            72
# Massachusetts     72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %%
df.Location.nunique()
# Out:
# 50

# %%
plt.figure(figsize=(16,6))
df.Location.value_counts()[:10].plot.bar(color=sns.color_palette("tab20"),edgecolor="k")
plt.xlabel("Location",weight="bold",fontsize=16,labelpad=20)
plt.ylabel("\nNumber of Occurrences",weight="bold",fontsize=13)
plt.xticks(rotation=0,ha="center",weight="bold")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
s=df.Size.value_counts()
plt.bar(x=s.index,height=s.values,color=sns.color_palette(),width=0.6)
for x,y in zip(s.index,s.values):
    plt.text(x,y+6,y,ha="center")
plt.tight_layout()
plt.xlabel("Size",labelpad=8,weight="bold",fontsize=12)
plt.ylabel("Number of Occurrences", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
df.Color.value_counts().nlargest(10).sort_values(ascending=True).plot.barh(
color=("maroon","gray","cyan","violet","black","green","teal","silver","yellow","olive"))
plt.xlabel("\nNumber of Occurrences", fontsize=12)
plt.ylabel("Color",size=13)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
s=df.Season.value_counts()
plt.bar(x=s.index,height=s.values,color=sns.color_palette(),width=0.5)
for x,y in zip(s.index,s.values):
    plt.text(x,y+7,y)
plt.xlabel("Season",fontsize=13,c="r")
plt.ylabel("\nNumber of Occurrences", fontsize=12,c="r")
plt.show()

# %%
plt.figure(figsize=(10,4))
df.Season.value_counts().plot(kind="pie",autopct='%1.1f%%')
plt.axis("equal")
plt.title("season",weight="bold",fontsize=12)
plt.legend(labels=s.index,loc =1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df["Subscription Status"].value_counts().plot.bar(color=sns.color_palette(),width=0.5)
plt.xticks(rotation=0,ha="center")
plt.title("Subscription Status\n",weight="bold",c="r",ha="center")
plt.xlabel("")
plt.ylabel("\nNumber of Occurrences", fontsize=12,c="r")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
df["Subscription Status"].value_counts().plot.pie(autopct="%1.1f%%",explode=(0,0.05),startangle=20)
plt.title("Subscription Status",weight="bold")
plt.legend(loc=1)
plt.axis("equal")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
s=df["Payment Method"].value_counts()
plt.bar(x=s.index,height=s.values,color=sns.color_palette(),width=0.5,align='center')
for x,y in zip(s.index,s.values):
    plt.text(x,y+5,y,ha="center")
plt.title("Payment Method\n",fontsize=13,ha="center",c="r")
plt.ylabel("\nNumber of Occurrences", fontsize=12,c="r")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
df["Payment Method"].value_counts().plot(kind="pie",autopct='%1.1f%%',startangle=20)
plt.axis("equal")
plt.title("Payment Method\n",weight="bold",fontsize=12)
plt.ylabel("")
plt.legend(loc =1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=df["Shipping Type"].value_counts()
plt.bar(x=ax.index,height=ax.values,color=sns.color_palette(),width=0.5)
for x,y in zip(ax.index,ax.values):
    plt.text(x,y+5,y,ha="center")
plt.title("Shipping Type\n",weight="bold",c="r")
plt.ylabel("\nNumber of Occurrences", fontsize=12,c="r")
plt.xticks(ha="center")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
df["Shipping Type"].value_counts().plot(kind="pie",autopct='%1.1f%%',startangle=20)
plt.axis("equal")
plt.title("Shipping Type\n",weight="bold",fontsize=12)
plt.ylabel("")
plt.legend(loc =1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=df["Frequency of Purchases"].value_counts()
plt.bar(x=ax.index,height=ax.values,color=sns.color_palette(),width=0.5)
for x,y in zip(ax.index,ax.values):
    plt.text(x,y+5,y,ha="center")
plt.title("Frequency of Purchases\n",weight="bold",c="r")
plt.ylabel("\nNumber of Occurrences", fontsize=12,c="r")
plt.xticks(ha="center")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
df["Frequency of Purchases"].value_counts().plot.pie(autopct='%1.1f%%',startangle=40)
plt.axis("equal")
plt.title("Frequency of Purchases\n",weight="bold",fontsize=12)
plt.ylabel("")
plt.legend(loc =1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What is the average age of customers in the dataset ?

# %%
print("Average Age of Customer:",df.Age.mean())
# Out:
# Average Age of Customer: 44.06846153846154

# %% [markdown]
# ### What is the most common item purchased ?

# %%
print("most common item purchased: ",df["Item Purchased"].mode()[0])
# Out:
# most common item purchased:  Blouse

# %% [markdown]
# ### What is the total purchase amount for each category

# %%
df.pivot_table(index="Category",values="Purchase Amount (USD)",aggfunc="sum")
#df.groupby(by="Category")[("Purchase Amount (USD)")].agg(["sum"])
# Out:
#              Purchase Amount (USD)
# Category
# Accessories                  74200
# Clothing                    104264
# Footwear                     36093
# Outerwear                    18524

# %% [markdown]
# ### What is the average review rating for male customers and female customers separately ?

# %%
df.groupby(by="Gender")[("Review Rating")].agg(["mean"])
# Out:
#             mean
# Gender
# Female  3.741426
# Male    3.753959

# %% [markdown]
# ### What is the most common payment method used by customers ?

# %%
most_common_payment_method = df['Payment Method'].mode()[0]
print("Most Common Payment Method:", most_common_payment_method)
# Out:
# Most Common Payment Method: Credit Card

# %% [markdown]
# ### What is the median purchase amount (USD) ?

# %%
df["Purchase Amount (USD)"].median()
# Out:
# 60.0

# %% [markdown]
# ### How many customers have opted for the Subscription ?

# %%
df[df["Subscription Status"]=="Yes"].shape[0]
# Out:
# 1053

# %% [markdown]
# ### What is the average purchase amount for customers with a subscription status of 'Yes' and 'No' ?

# %%
df.groupby(by="Subscription Status")[("Purchase Amount (USD)")].agg(["mean"])
# Out:
#                           mean
# Subscription Status
# No                   59.865121
# Yes                  59.491928

# %% [markdown]
# ### What is the most common season for purchases ?

# %%
df.Season.mode()[0]
# Out:
# 'Spring'

# %% [markdown]
# ### What is the total purchase amount for each gender ?

# %%
df.groupby(by="Gender")["Purchase Amount (USD)"].agg(["sum"])
# Out:
#            sum
# Gender
# Female   75191
# Male    157890

# %% [markdown]
# ### What is the average age of customers who made purchases in the Summer season ?

# %%
print("average age of customers who made purchases in the Summer season :",df[df.Season=="Summer"].Age.mean())
# Out:
# average age of customers who made purchases in the Summer season : 43.973821989528794

# %% [markdown]
# ### How many customers used a promo code for their purchase ?

# %%
df[df["Promo Code Used"]=="Yes"]["Customer ID"].count()
# Out:
# 1677

# %% [markdown]
# ### What is the maximum and minimum review rating in the dataset ?

# %%
print("maximum review rating :",df["Review Rating"].max())
print("minimum review rating :",df["Review Rating"].min())
# Out:
# maximum review rating : 5.0
# minimum review rating : 2.5

# %% [markdown]
# ### What is the most common shipping type for customers with a review rating above 4 ?

# %%
df[df["Review Rating"]>=4]["Shipping Type"].mode()[0]
# Out:
# 'Standard'

# %% [markdown]
# ### How many customers have made more than 30 previous purchases ?

# %%
df[df["Previous Purchases"]>30]["Customer ID"].count()
# Out:
# 1549

# %% [markdown]
# ### What is the average purchase amount for customers who have made more than 30 previous purchases ?

# %%
df[df["Previous Purchases"]>30]["Purchase Amount (USD)"].mean()
# Out:
# 60.02840542285345

# %% [markdown]
# ### What is the most common payment method for customers who shop in the Winter season ?

# %%
df[df.Season=="Winter"]["Payment Method"].mode([0])
# Out:
# 0    Credit Card
# Name: Payment Method, dtype: object

# %% [markdown]
# ### What is the total purchase amount for customers with a 'Free Shipping' shipping type ?

# %%
df[df["Shipping Type"]=="Free Shipping"]["Purchase Amount (USD)"].sum()
# Out:
# 40777

# %% [markdown]
# ### What is the average purchase amount for customers who used a discount ?

# %%
df[df["Discount Applied"]=="Yes"]["Purchase Amount (USD)"].mean()
# Out:
# 59.27906976744186

# %% [markdown]
# ### What is the most common category of items purchased by female customers with a review rating below 3 ?

# %%
df[(df["Review Rating"]<3) & (df.Gender=="Female")]["Item Purchased"].mode()[0]
# Out:
# 'Pants'

# %% [markdown]
# ### What is the average age of customers who made purchases with a review rating above 4 and used a promo code?

# %%
df[(df["Review Rating"]>4) & (df["Promo Code Used"]=="Yes")].Age.mean()
# Out:
# 43.9872

# %% [markdown]
# ### What is the total purchase amount for customers in each location ?

# %%
df.groupby(by="Location")["Purchase Amount (USD)"].agg(["sum"])
# Out:
#                  sum
# Location
# Alabama         5261
# Alaska          4867
# Arizona         4326
# Arkansas        4828
# California      5605
# Colorado        4222
# Connecticut     4226
# Delaware        4758
# Florida         3798
# Georgia         4645
# Hawaii          3752
# Idaho           5587
# Illinois        5617
# Indiana         4655
# Iowa            4201
# Kansas          3437
# Kentucky        4402
# Louisiana       4848
# Maine           4388
# Maryland        4795
# Massachusetts   4384
# Michigan        4533
# Minnesota       4977
# Mississippi     4883
# Missouri        4691
# Montana         5784
# Nebraska        5172
# Nevada          5514
# New Hampshire   4219
# New Jersey      3802
# New Mexico      5014
# New York        5257
# North Carolina  4742
# North Dakota    5220
# Ohio            4649
# Oklahoma        4376
# Oregon          4243
# Pennsylvania    4926
# Rhode Island    3871
# South Carolina  4439
# South Dakota    4236
# Tennessee       4772
# ...

# %% [markdown]
# ### What is the average purchase amount for customers who have a subscription and used Venmo as the payment method ?

# %%
df[(df["Subscription Status"]=="Yes") & (df["Payment Method"]=="Venmo")]["Purchase Amount (USD)"].mean()
# Out:
# 60.71264367816092

# %% [markdown]
# ### What is the frequency distribution of the 'Frequency of Purchases' column ?

# %%
df["Frequency of Purchases"].value_counts()
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %% [markdown]
# ### What is the average purchase amount for each color of items ?

# %%
df.groupby("Color")["Purchase Amount (USD)"].agg(["mean"])
# Out:
#                 mean
# Color
# Beige      60.414966
# Black      58.401198
# Blue       56.953947
# Brown      59.063830
# Charcoal   60.633987
# Cyan       61.891566
# Gold       61.007246
# Gray       62.490566
# Green      65.704142
# Indigo     56.251701
# Lavender   59.129252
# Magenta    57.131579
# Maroon     59.525316
# Olive      58.146893
# Orange     60.889610
# Peach      59.187919
# Pink       60.588235
# Purple     60.013245
# Red        59.317568
# Silver     56.832370
# Teal       60.808140
# Turquoise  55.613793
# Violet     61.716867
# White      62.640845
# Yellow     59.241379

# %% [markdown]
# ### KDE plot for Purchase Amount by Season

# %%
plt.figure(figsize=(20,5))
sns.kdeplot(data=df,x="Purchase Amount (USD)",hue="Season",common_norm=False,fill=True,palette="Set1")
plt.title("KDE plot for Purchase Amount by Season",weight="bold",fontsize=12)
plt.xlabel("Purchase Amount  in USD",size=13)
plt.show()

# %% [markdown]
# ### What is the most common payment method for customers who purchased items in the Fall season ?

# %%
df[df.Season=="Fall"]["Payment Method"].mode()[0]
# Out:
# 'Credit Card'

# %% [markdown]
# ### How many customers have made a purchase in each category ?

# %%
#Purchase count by Category
df.Category.value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %% [markdown]
# ### What is the average age of customers who purchased accessories with a discount applied ?

# %%
df[(df.Category=="Accessories") & (df["Discount Applied"]=="Yes")].Age.mean()
# Out:
# 44.23941068139963

# %% [markdown]
# ### What is the total purchase amount for each size of clothing items (XL, L, M, S) ?

# %%
df.groupby("Size")["Purchase Amount (USD)"].agg(["sum"])
# Out:
#          sum
# Size
# L      61667
# M     105167
# S      40468
# XL     25779

# %% [markdown]
# ### What is the total purchase amount for customers who have made more than 40 previous purchases ?

# %%
df[df["Previous Purchases"]>40]["Purchase Amount (USD)"].sum()
# Out:
# 46590

# %% [markdown]
# ### What is the most common location for customers who purchased socks with a discount applied ?

# %%
df[(df["Item Purchased"]=="Socks") & (df["Discount Applied"]=="Yes")].Location.mode()[0]
# Out:
# 'Georgia'

# %% [markdown]
# ### What is the average purchase amount for customers who have a subscription and used Venmo as the payment method, but did not use a promo code ?

# %%
df[(df["Subscription Status"]=="Yes") & (df["Payment Method"]=="Venmo") & (df["Promo Code Used"]=="No")]["Purchase Amount (USD)"].mean()
# Out:
# nan

# %%
df["Promo Code Used"].value_counts()
# Out:
# Promo Code Used
# No     2223
# Yes    1677
# Name: count, dtype: int64

# %% [markdown]
# ### What is the most common item purchased by customers in Louisiana with a review rating of 4 or higher ?

# %%
df[(df.Location=="Louisiana") & (df["Review Rating"]>=4)]["Item Purchased"].mode()
# Out:
# 0    Sweater
# Name: Item Purchased, dtype: object

# %% [markdown]
# ### What is the total purchase amount for customers who made purchases in the Fall season and used a credit card as the payment method ?

# %%
df[(df.Season=="Fall") & (df["Payment Method"]=="Debit Card")]["Purchase Amount (USD)"].sum()
# Out:
# 10283

# %% [markdown]
# ### What is the most common category of items purchased by male customers in the Winter season with a review rating below 3 ?

# %%
df[(df.Gender=="Male") & (df.Season=="Winter") & (df["Review Rating"]<3)]["Item Purchased"].mode()
# Out:
# 0    Sunglasses
# Name: Item Purchased, dtype: object

# %% [markdown]
# ### How many customers have a subscription status of 'Yes' and used a promo code for their purchase ?

# %%
df[(df["Subscription Status"]=="Yes") & (df["Promo Code Used"]=="Yes")]["Customer ID"].count()
# Out:
# 1053

# %% [markdown]
# ### What is the correlation between a customer's age and their total previous purchases? Calculate the Pearson correlation coefficient

# %%
df.Age.corr(df["Previous Purchases"],method="pearson")
# Out:
# 0.04044453114289466

# %% [markdown]
# ### Histogram of Age Distribution

# %%
plt.figure(figsize=(15,6))
plt.hist(x=df.Age,bins=20,color="#0BC224",edgecolor="k")
plt.xlabel("Age Distibution", fontsize=15,ha="center",color="darkred")
plt.ylabel("Frequency\n",fontsize=15,ha="center",color="darkred")
plt.show()

# %% [markdown]
# ### Box Plot of Purchase Amount by Gender

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x="Gender",y="Purchase Amount (USD)",data=df)
plt.title("Purchase Amount by Gender\n",fontsize=17,color="r",ha="center")
plt.xlabel("Gender",fontsize=14,color="r")
plt.ylabel("Purchase Amount in USD\n", fontsize=15,color="r")
plt.xticks(fontsize=12,color="darkgreen")
plt.show()

# %% [markdown]
# ### Scatter Plot of Age vs. Review Rating

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x="Age",y="Review Rating",data=df)
plt.title('Age vs. Review Rating\n',size=15)
plt.xlabel('Age',size=15)
plt.ylabel('Review Rating',size=15)
plt.show()

# %%
df.head(3)
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
#
#         Location Size   Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L    Gray  Winter            3.1                 Yes
# 1          Maine    L  Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S  Maroon  Spring            3.1                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# ...

# %% [markdown]
# ### Stacked Bar Chart of Subscription Status by Gender

# %%
stac=df.groupby(["Gender","Subscription Status"]).size().unstack()

plt.figure(figsize=(20,6))
stac.plot(kind="bar",stacked=True,rot=0,color=sns.color_palette())
plt.title('Subscription Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
